# %% [markdown]
# # Best models
#
# This notebook aims to retrieve the best model object we have based on a metric (e.g. balanced accuracy) for all seeds
#
# 10 models for each (model type, dataset, version, normalization) combination have been trained with different 10 seeds
# => get the best model of them (best seed)
#
# This can be important in the interpretability part, for instance in SHAP we need to take as input a trained model, can not have an aggregated one (so it's like we're performing grid search on seeds), wjile methodologically speaking we can not cherry pick such models when comparing models all together, the aim here would be biological relevance so we would want the model that portray the best predictive power as we believe it will be best in showing the embedding features that are most contributing to the discrimination between healthy and sepsis

# %%
import pandas as pd

all_df=pd.read_csv('../../results/score_tables/scores_all_seeds.csv')

# %%
all_df
# Out:
#               model                            input normalization  \
# 0     random_forest       Complex_protein_embeddings          none
# 1     random_forest        Complex_sample_embeddings          none
# 2     random_forest  concatenated_protein_embeddings          none
# 3     random_forest   concatenated_sample_embeddings          none
# 4     random_forest                  gene_expression          none
# ...             ...                              ...           ...
# 1475            svm  concatenated_protein_embeddings        minmax
# 1476            svm          RGCN_protein_embeddings        minmax
# 1477        xgboost       Complex_protein_embeddings        minmax
# 1478        xgboost  concatenated_protein_embeddings        minmax
# 1479        xgboost          RGCN_protein_embeddings        minmax
#
#          version  balanced_accuracy  precision    recall        f1       mcc  \
# 0          v2.10           0.778708   0.897436  0.921053  0.909091  0.577079
# 1          v2.10           0.500000   0.775510  1.000000  0.873563  0.000000
# 2          v2.10           0.824163   0.921053  0.921053  0.921053  0.648325
# 3          v2.10           0.577751   0.804348  0.973684  0.880952  0.270636
# 4     no version           0.714115   0.860465  0.973684  0.913580  0.545073
# ...          ...                ...        ...       ...       ...       ...
# 1475       v2.11           0.875598   0.969697  0.842105  0.901408  0.668382
# 1476       v2.11           0.875598   0.969697  0.842105  0.901408  0.668382
# 1477       v2.11           0.706938   0.868421  0.868421  0.868421  0.413876
# 1478       v2.11           0.706938   0.868421  0.868421  0.868421  0.413876
# 1479       v2.11           0.837321   0.923077  0.947368  0.935065  0.698439
#
#          auroc     auprc     brier  seed
# 0     0.925837  0.979335  0.098828     0
# 1     0.270335  0.675974  0.201608     0
# 2     0.947368  0.985782  0.085299     0
# 3     0.478469  0.798355  0.190975     0
# 4     0.921053  0.976706  0.105057     0
# ...        ...       ...       ...   ...
# 1475  0.933014  0.980298  0.095506     9
# 1476  0.933014  0.980298  0.095506     9
# 1477  0.918660  0.978005  0.110757     9
# 1478  0.918660  0.977969  0.112612     9
# 1479  0.858852  0.949220  0.104396     9
#
# [1480 rows x 13 columns]

# %%
# -- group by: model, input, normalization, version and getting the max balanced accuracy
best_models = all_df.loc[all_df.groupby(['model','input','normalization','version'])['balanced_accuracy'].idxmax()]
best_models
# Out:
#               model                            input normalization  \
# 348   random_forest       Complex_protein_embeddings         log1p
# 1160  random_forest       Complex_protein_embeddings         log1p
# 1100  random_forest       Complex_protein_embeddings        minmax
# 876   random_forest       Complex_protein_embeddings        minmax
# 296   random_forest       Complex_protein_embeddings          none
# ...             ...                              ...           ...
# 790         xgboost  concatenated_protein_embeddings      standard
# 122         xgboost  concatenated_protein_embeddings      standard
# 24          xgboost   concatenated_sample_embeddings          none
# 393         xgboost   concatenated_sample_embeddings          none
# 469         xgboost                  gene_expression          none
#
#          version  balanced_accuracy  precision    recall        f1       mcc  \
# 348        v2.10           0.954545   0.974359  1.000000  0.987013  0.941159
# 1160       v2.11           0.909091   0.950000  1.000000  0.974359  0.881631
# 1100       v2.10           0.954545   0.974359  1.000000  0.987013  0.941159
# 876        v2.11           0.909091   0.950000  1.000000  0.974359  0.881631
# 296        v2.10           0.941388   0.973684  0.973684  0.973684  0.882775
# ...          ...                ...        ...       ...       ...       ...
# 790        v2.10           0.551435   0.795455  0.921053  0.853659  0.141798
# 122        v2.11           0.583732   0.809524  0.894737  0.850000  0.199681
# 24         v2.10           0.564593   0.800000  0.947368  0.867470  0.196865
# 393        v2.11           0.759569   0.880952  0.973684  0.925000  0.619010
# 469   no version           0.941388   0.973684  0.973684  0.973684  0.882775
#
#          auroc     auprc     brier  seed
# 348   0.997608  0.999325  0.042023     2
# 1160  1.000000  1.000000  0.055732     7
# 1100  0.997608  0.999325  0.046440     7
# 876   0.997608  0.999325  0.065387     5
# 296   0.992823  0.998074  0.046525     2
# ...        ...       ...       ...   ...
# 790   0.655502  0.841143  0.181915     5
# 122   0.715311  0.877203  0.162022     0
# 24    0.459330  0.773625  0.200869     0
# 393   0.901914  0.967005  0.100349     2
# 469   0.976077  0.993036  0.053652     3
#
# [148 rows x 13 columns]

# %%
best_models.to_csv('../../results/score_tables/best_models_all_seeds_scores.csv', index=False)

# %%
MAIN_DUMP='../../dump_seeds/'
best_model_dump='../../dump/best_models/'

for item in best_models.itertuples():
    model_name=item.model
    input_name=item.input
    normalization=item.normalization
    version=item.version
    seed=item.seed

    # -- gene exp has no version so this is to fix since its training and retrieval are set to a default version of 2.10
    if input_name=='gene_expression':
        version='v2.10'

    source_path=f"{MAIN_DUMP}dump_{seed}/{version}_{normalization}/{model_name}_{input_name}_gridsearch_model.joblib"
    target_path=f"{best_model_dump}{version}_{normalization}/"
    joblib_file=f'{model_name}_{input_name}_gridsearch_model.joblib'

    # !mkdir -p {target_path}
    # !cp -r {source_path}* {target_path}{joblib_file}

# %% [markdown]
# We only care for protein embeddings dataset for the interpretability part (and maybe gene expressio)
# we will also remove those normalized by standard or robust approaches as they are not performing well overall

# %%
best_models=best_models[(best_models['input'].str.endswith('protein_embeddings')) & (best_models['normalization']!='standard') & (best_models['normalization']!='robust')]

# %% [markdown]
# ### v2.10

# %%
best_models[best_models['version']=='v2.10']
# Out:
#               model                            input normalization version  \
# 348   random_forest       Complex_protein_embeddings         log1p   v2.10
# 1100  random_forest       Complex_protein_embeddings        minmax   v2.10
# 296   random_forest       Complex_protein_embeddings          none   v2.10
# 350   random_forest          RGCN_protein_embeddings         log1p   v2.10
# 510   random_forest          RGCN_protein_embeddings        minmax   v2.10
# 449   random_forest          RGCN_protein_embeddings          none   v2.10
# 793   random_forest  concatenated_protein_embeddings         log1p   v2.10
# 805   random_forest  concatenated_protein_embeddings        minmax   v2.10
# 1334  random_forest  concatenated_protein_embeddings          none   v2.10
# 1387    sklearn_mlp       Complex_protein_embeddings         log1p   v2.10
# 67      sklearn_mlp       Complex_protein_embeddings        minmax   v2.10
# 1191    sklearn_mlp       Complex_protein_embeddings          none   v2.10
# 57      sklearn_mlp          RGCN_protein_embeddings         log1p   v2.10
# 69      sklearn_mlp          RGCN_protein_embeddings        minmax   v2.10
# 12      sklearn_mlp          RGCN_protein_embeddings          none   v2.10
# 56      sklearn_mlp  concatenated_protein_embeddings         log1p   v2.10
# 216     sklearn_mlp  concatenated_protein_embeddings        minmax   v2.10
# 9       sklearn_mlp  concatenated_protein_embeddings          none   v2.10
# 58              svm       Complex_protein_embeddings         log1p   v2.10
# 366             svm       Complex_protein_embeddings        minmax   v2.10
# 14              svm       Complex_protein_embeddings          none   v2.10
# 1244            svm          RGCN_protein_embeddings         log1p   v2.10
# 368             svm          RGCN_protein_embeddings        minmax   v2.10
# 1055            svm          RGCN_protein_embeddings          none   v2.10
# 355             svm  concatenated_protein_embeddings         log1p   v2.10
# 367             svm  concatenated_protein_embeddings        minmax   v2.10
# 1052            svm  concatenated_protein_embeddings          none   v2.10
# 357         xgboost       Complex_protein_embeddings         log1p   v2.10
# 665         xgboost       Complex_protein_embeddings        minmax   v2.10
# 1057        xgboost       Complex_protein_embeddings          none   v2.10
# 359         xgboost          RGCN_protein_embeddings         log1p   v2.10
# 371         xgboost          RGCN_protein_embeddings        minmax   v2.10
# 470         xgboost          RGCN_protein_embeddings          none   v2.10
# 802         xgboost  concatenated_protein_embeddings         log1p   v2.10
# 666         xgboost  concatenated_protein_embeddings        minmax   v2.10
# 1059        xgboost  concatenated_protein_embeddings          none   v2.10
#
#       balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 348            0.954545   0.974359  1.000000  0.987013  0.941159  0.997608
# 1100           0.954545   0.974359  1.000000  0.987013  0.941159  0.997608
# 296            0.941388   0.973684  0.973684  0.973684  0.882775  0.992823
# 350            0.687799   0.853659  0.921053  0.886076  0.424009  0.777512
# 510            0.720096   0.871795  0.894737  0.883117  0.455719  0.708134
# 449            0.655502   0.837209  0.947368  0.888889  0.395863  0.696172
# 793            0.954545   0.974359  1.000000  0.987013  0.941159  0.997608
# 805            0.954545   0.974359  1.000000  0.987013  0.941159  1.000000
# 1334           0.928230   0.972973  0.947368  0.960000  0.831005  0.935407
