# %% [markdown]
# # MLP robustness

# %% [markdown]
# this notebook aims to investigate the robustness of MLP models, both `sklearn` and `pytorch` implementations, to out data (mainly on `Complex_protein_embeddings` that is showing good results).
#
# Will be training the same model several times and evaluating the variance of the results.

# %%
import sys,os
sys.path.append(os.path.abspath('../../src/ml'))

from load_matrix import load_df
from model_trainer import MLModel
from evaluator import Evaluator
from collector import ResultsCollector
from visualizer import DashboardVisualizer
import pandas as pd

# %%
df=load_df('gene_expression')

# %% [markdown]
# ## sklearn

# %%
mlp_classifiers={}
number_of_trials=10
norm='none'
version='2.10'
MLModel.DEFAULT_SAVE #--not interested in saving the model
# Out:
# False

# %%
for i in range(number_of_trials):
    model=MLModel(dataset_name='gene_expression',df=df,model_type='sklearn_mlp',version=version,normalization=norm)
    model.train_evaluate()
    mlp_classifiers[i]=model
# Out:
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (100, 50)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (100,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.1
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.1, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (100, 50)
#   learning_rate_init: 0.001
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.001, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (100,)
#   learning_rate_init: 0.1
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.1, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.1
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.1, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (100, 50)
#   learning_rate_init: 0.001
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.001, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (100,)
#   learning_rate_init: 0.1
#   solver: adam
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.1, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --

# %% [markdown]
# ## pytorch

# %%
# mlp_classifiers={}
# number_of_trials=10
# norm='none'
# version='2.10'
# MLModel.DEFAULT_SAVE #--not interested in saving the model
# Out:
# False

# %%
# for i in range(number_of_trials):
#     model=MLModel(dataset_name='Comlex_protein_embeddings',df=df,model_type='pytorch_mlp',version=version,normalization=norm)
#     model.train_evaluate()
#     mlp_classifiers[i]=model

# %% [markdown]
# ## evaluation

# %%
collector = ResultsCollector()
metrics_list = []
for i, ml_model in mlp_classifiers.items():
        print(f'-- Evaluating model{i}: {version} {norm} --')
        y_test, y_pred, y_proba = ml_model.y_test, ml_model.y_pred, ml_model.y_proba
        metrics = Evaluator(y_test, y_pred, y_proba).compute_metrics()
        metrics_list.append({
                        "model": ml_model.model_type,
                        "input": ml_model.dataset_name,
                        "normalization": norm,  
                        "version": version,
                        **metrics
                })

        collector.add(ml_model.model_type, ml_model.dataset_name, y_test, y_pred, y_proba)
results=pd.DataFrame(metrics_list)
# Out:
# -- Evaluating model0: 2.10 none --
# -- Evaluating model1: 2.10 none --
# -- Evaluating model2: 2.10 none --
# -- Evaluating model3: 2.10 none --
# -- Evaluating model4: 2.10 none --
# -- Evaluating model5: 2.10 none --
# -- Evaluating model6: 2.10 none --
# -- Evaluating model7: 2.10 none --
# -- Evaluating model8: 2.10 none --
# -- Evaluating model9: 2.10 none --

# %%
results
# Out:
#          model            input normalization version  balanced_accuracy  \
# 0  sklearn_mlp  gene_expression          none    2.10           0.928571
# 1  sklearn_mlp  gene_expression          none    2.10           1.000000
# 2  sklearn_mlp  gene_expression          none    2.10           0.785714
# 3  sklearn_mlp  gene_expression          none    2.10           0.837912
# 4  sklearn_mlp  gene_expression          none    2.10           0.980769
# 5  sklearn_mlp  gene_expression          none    2.10           0.961538
# 6  sklearn_mlp  gene_expression          none    2.10           0.980769
# 7  sklearn_mlp  gene_expression          none    2.10           0.818681
# 8  sklearn_mlp  gene_expression          none    2.10           0.909341
# 9  sklearn_mlp  gene_expression          none    2.10           0.890110
#
#    precision    recall        f1       mcc     auroc     auprc     brier
# 0   0.962963  1.000000  0.981132  0.908514  1.000000  1.000000  0.020148
# 1   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  0.014521
# 2   0.896552  1.000000  0.945455  0.715762  0.901099  0.954977  0.090989
# 3   0.925926  0.961538  0.943396  0.716328  0.906593  0.966990  0.087382
# 4   1.000000  0.961538  0.980392  0.917249  1.000000  1.000000  0.030303
# 5   1.000000  0.923077  0.960000  0.847319  0.989011  0.997096  0.059941
# 6   1.000000  0.961538  0.980392  0.917249  1.000000  1.000000  0.030303
# 7   0.923077  0.923077  0.923077  0.637363  0.967033  0.991445  0.084155
# 8   0.961538  0.961538  0.961538  0.818681  0.994505  0.998575  0.047230
# 9   0.960000  0.923077  0.941176  0.744282  0.923077  0.960173  0.090909

# %%
MLModel.SKLEARN_MLP_HYPERPARAMS
# Out:
# {'hidden_layer_sizes': [(50,), (100,), (100, 50)],
#  'activation': ['relu'],
#  'solver': ['adam', 'sgd'],
#  'learning_rate_init': [0.001, 0.01, 0.1]}

# %%
MLModel.PYTORCH_MLP_HYPERPARAMS
# Out:
# {'hidden_layer_sizes': [(50,), (100,), (100, 50)],
#  'activation': ['relu', 'leaky_relu'],
#  'solver': ['adam', 'sgd'],
#  'learning_rate_init': [0.001, 0.01, 0.1],
#  'batch_size': [16]}
