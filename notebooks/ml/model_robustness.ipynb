# %% [markdown]
# # MLP robustness

# %% [markdown]
# THIS NOTEBOOK IS NOT TO BE RERAN (SOME CELLS ARE OVERRIDDEN OR NOT IN THE CORRECT ORDER)
# IT'S ONLY TO SHOW RESULTS (experimentation)

# %% [markdown]
# this notebook aims to investigate the robustness of MLP models, both `sklearn` and `pytorch` implementations, to out data (mainly on `Complex_protein_embeddings` that is showing good results) (extended to other models too)
#
# Will be training the same model several times and evaluating the variance of the results.

# %%
import sys,os
sys.path.append(os.path.abspath('../../src/ml'))

from load_matrix import load_df
from model_trainer import MLModel
from evaluator import Evaluator
from collector import ResultsCollector
from visualizer import DashboardVisualizer
import pandas as pd

# %%
dataset='Complex_protein_embeddings'

# %%
df=load_df(dataset)
# Out:
#  Complex embeddings detected in /mnt/c/Users/rayan/Documents/saclay/courses/deep-learning-and-artifical-intelligence/project/2526-m2geniomhe-GNN-sepsis/models/executions/GSE54514_enriched_ontology_degfilterv2.9/outputmodel_Complex_entity_embeddings.npy, splitting real+imag.

# %% [markdown]
# ## prep

# %% [markdown]
# ### xgboost

# %%
xgboost_classifiers={}
number_of_trials=10
norm='none'
version='2.10'

# %%
seed=1

# %%
for i in range(number_of_trials):
    model=MLModel(dataset_name=dataset,df=df,model_type='xgboost',version=version,normalization=norm,random_state=i)
    model.train_evaluate()
    xgboost_classifiers[i]=model
# Out:
# -- [xgboost_gene_expression] Initialized MLModel with model_type='XGBOOST', dataset_name='GENE_EXPRESSION' --
# -- [xgboost_gene_expression] split ratio: 0.2
# -- [xgboost_gene_expression] random state: 0
# -- [xgboost_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] Training XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- XGBoost Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   learning_rate: [0.01, 0.1, 0.2]
#   subsample: [0.6, 0.8, 1.0]
#   scale_pos_weight: [0.28346456692913385, 0.4, 0.2]
#
#
#
# -- Best Parameters --
#   learning_rate: 0.1
#   max_depth: 3
#   n_estimators: 100
#   scale_pos_weight: 0.4
#   subsample: 0.8
#
#
# -- [xgboost_gene_expression] best model parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'scale_pos_weight': 0.4, 'subsample': 0.8} --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] predicting XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [xgboost_gene_expression] Initialized MLModel with model_type='XGBOOST', dataset_name='GENE_EXPRESSION' --
# -- [xgboost_gene_expression] split ratio: 0.2
# -- [xgboost_gene_expression] random state: 1
# -- [xgboost_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] Training XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- XGBoost Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   learning_rate: [0.01, 0.1, 0.2]
#   subsample: [0.6, 0.8, 1.0]
#   scale_pos_weight: [0.28346456692913385, 0.4, 0.2]
#
#
#
# -- Best Parameters --
#   learning_rate: 0.2
#   max_depth: 3
#   n_estimators: 200
#   scale_pos_weight: 0.28346456692913385
#   subsample: 0.8
#
#
# -- [xgboost_gene_expression] best model parameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200, 'scale_pos_weight': 0.28346456692913385, 'subsample': 0.8} --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] predicting XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [xgboost_gene_expression] Initialized MLModel with model_type='XGBOOST', dataset_name='GENE_EXPRESSION' --
# -- [xgboost_gene_expression] split ratio: 0.2
# -- [xgboost_gene_expression] random state: 2
# -- [xgboost_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] Training XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- XGBoost Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   learning_rate: [0.01, 0.1, 0.2]
#   subsample: [0.6, 0.8, 1.0]
#   scale_pos_weight: [0.28346456692913385, 0.4, 0.2]
#
#
#
# -- Best Parameters --
#   learning_rate: 0.1
#   max_depth: 3
#   n_estimators: 100
#   scale_pos_weight: 0.2
#   subsample: 0.8
#
#
# -- [xgboost_gene_expression] best model parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'scale_pos_weight': 0.2, 'subsample': 0.8} --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] predicting XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [xgboost_gene_expression] Initialized MLModel with model_type='XGBOOST', dataset_name='GENE_EXPRESSION' --
# -- [xgboost_gene_expression] split ratio: 0.2
# -- [xgboost_gene_expression] random state: 3
# -- [xgboost_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [xgboost_gene_expression] Training XGBOOST model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- XGBoost Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   learning_rate: [0.01, 0.1, 0.2]
#   subsample: [0.6, 0.8, 1.0]
#   scale_pos_weight: [0.28346456692913385, 0.4, 0.2]

# %%
classifiers=xgboost_classifiers.copy()

# %% [markdown]
# ### svm

# %%
svm_classifiers={}
number_of_trials=10
norm='none'
version='2.10'

# %%
for i in range(number_of_trials):
    model=MLModel(dataset_name=dataset,df=df,model_type='svm',version=version,normalization=norm)
    model.train_evaluate()
    svm_classifiers[i]=model
# Out:
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# -- [svm_Complex_protein_embeddings] setting SYSOUT_FILE to: svm_Complex_protein_embeddings_2.10_none_training_utils.log --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [svm_Complex_protein_embeddings] Initialized MLModel with model_type='SVM', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [svm_Complex_protein_embeddings] split ratio: 0.2
# -- [svm_Complex_protein_embeddings] random state: 42
# -- [svm_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] Training SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- SVM Hyperparameters --
#   C: [0.1, 1]
#   kernel: ['linear', 'rbf']
#   gamma: ['scale', 'auto']
#   class_weight: ['balanced', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   C: 1
#   class_weight: balanced
#   gamma: auto
#   kernel: rbf
#
#
# -- [svm_Complex_protein_embeddings] best model parameters: {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'} --
# --------------------------------------------------------------------------------
# -- [svm_Complex_protein_embeddings] predicting SVM model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --

# %%
classifiers=svm_classifiers.copy()

# %% [markdown]
# ### random forest

# %%
rf_classifiers={}
number_of_trials=10
norm='none'
version='2.10'

# %%
for i in range(number_of_trials):
    model=MLModel(dataset_name=dataset,df=df,model_type='random_forest',version=version,normalization=norm)
    model.train_evaluate()
    rf_classifiers[i]=model
# Out:
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [random_forest_Complex_protein_embeddings] Initialized MLModel with model_type='RANDOM_FOREST', dataset_name='COMPLEX_PROTEIN_EMBEDDINGS' --
# -- [random_forest_Complex_protein_embeddings] split ratio: 0.2
# -- [random_forest_Complex_protein_embeddings] random state: 42
# -- [random_forest_Complex_protein_embeddings] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] Training RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- Random Forest Hyperparameters --
#   n_estimators: [50, 100, 200]
#   max_depth: [3, 5, 7]
#   min_samples_split: [2, 5, 10]
#   class_weight: ['balanced', 'balanced_subsample', {0: 2, 1: 1}, {0: 3, 1: 1}]
#
#
#
# -- Best Parameters --
#   class_weight: balanced
#   max_depth: 5
#   min_samples_split: 2
#   n_estimators: 200
#
#
# -- [random_forest_Complex_protein_embeddings] best model parameters: {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200} --
# --------------------------------------------------------------------------------
# -- [random_forest_Complex_protein_embeddings] predicting RANDOM_FOREST model on dataset 'Complex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --

# %%
classifiers=rf_classifiers.copy()

# %% [markdown]
# ### sklearn

# %%
mlp_classifiers={}
number_of_trials=10
norm='none'
version='2.10'
MLModel.DEFAULT_SAVE #--not interested in saving the model
# Out:
# False

# %%
for i in range(number_of_trials):
    model=MLModel(dataset_name=dataset,df=df,model_type='sklearn_mlp',version=version,normalization=norm)
    model.train_evaluate()
    mlp_classifiers[i]=model
# Out:
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --
# -- [sklearn_mlp_gene_expression] Initialized MLModel with model_type='SKLEARN_MLP', dataset_name='GENE_EXPRESSION' --
# -- [sklearn_mlp_gene_expression] split ratio: 0.2
# -- [sklearn_mlp_gene_expression] random state: 42
# -- [sklearn_mlp_gene_expression] CACHE_DIR is: .cache/ --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] Training SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,), (100, 50)]
#   activation: ['relu']
#   solver: ['adam', 'sgd']
#   learning_rate_init: [0.001, 0.01, 0.1]
#
#
#
# -- Best Parameters --
#   activation: relu
#   hidden_layer_sizes: (50,)
#   learning_rate_init: 0.001
#   solver: sgd
#
#
# -- [sklearn_mlp_gene_expression] best model parameters: {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate_init': 0.001, 'solver': 'sgd'} --
# --------------------------------------------------------------------------------
# -- [sklearn_mlp_gene_expression] predicting SKLEARN_MLP model on dataset 'gene_expression' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --

# %% [markdown]
# ### pytorch

# %% [markdown]
# better run on gpu

# %%
mlp_classifiers={}
number_of_trials=10
norm='none'
version='2.10'
MLModel.DEFAULT_SAVE #--not interested in saving the model
# Out:
# False

# %% [markdown]
# trial on 30 epochs

# %%
for i in range(number_of_trials):
    model=MLModel(dataset_name='Comlex_protein_embeddings',df=df,model_type='pytorch_mlp',version=version,normalization=norm,random_state=i)
    model.train_evaluate()
    mlp_classifiers[i]=model
# Out:
# -- [pytorch_mlp_Comlex_protein_embeddings] Initialized MLModel with model_type='PYTORCH_MLP', dataset_name='COMLEX_PROTEIN_EMBEDDINGS' --
# -- [pytorch_mlp_Comlex_protein_embeddings] split ratio: 0.2
# -- [pytorch_mlp_Comlex_protein_embeddings] random state: 0
# -- [pytorch_mlp_Comlex_protein_embeddings] CACHE_DIR is: .cache/ --
# -- [pytorch_mlp_Comlex_protein_embeddings] setting SYSOUT_FILE to: pytorch_mlp_Comlex_protein_embeddings_2.10_none_training_utils.log --
# --------------------------------------------------------------------------------
# -- [pytorch_mlp_Comlex_protein_embeddings] Training PYTORCH_MLP model on dataset 'Comlex_protein_embeddings' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
#   hidden_layer_sizes: [(50,), (100,)]
#   max_iter: [30]
#   activation: ['relu']
#   solver: ['adam', 'adamW']
#   learning_rate_init: [0.001, 0.0001]
#   batch_size: [16]
#   dropout_rate: [0.0, 0.1]
# -- [pytorch mlp] epoch 1/30, loss: 0.7027 --
# -- [pytorch mlp] epoch 1/30, loss: 1.9327 --
# -- [pytorch mlp] epoch 19/30, loss: 0.1781 --
# -- [pytorch mlp] epoch 20/30, loss: 0.1633 --
# -- [pytorch mlp] epoch 21/30, loss: 0.1557 --
# -- [pytorch mlp] epoch 22/30, loss: 0.1467 --
# -- [pytorch mlp] epoch 23/30, loss: 0.1362 --
# -- [pytorch mlp] epoch 24/30, loss: 0.1259 --
# -- [pytorch mlp] epoch 25/30, loss: 0.1289 --
# -- [pytorch mlp] epoch 26/30, loss: 0.1248 --
# -- [pytorch mlp] epoch 27/30, loss: 0.1162 --
# -- [pytorch mlp] epoch 28/30, loss: 0.1123 --
# -- [pytorch mlp] epoch 29/30, loss: 0.1044 --
# -- [pytorch mlp] epoch 30/30, loss: 0.0987 --
# -- training loss plot saved to: .cache/pytorch_mlp_plots/Comlex_protein_embeddings_2.10_none_train_loss.png in .cache/pytorch_mlp_plots/
#
# -- Best Parameters --
#   activation: relu
#   batch_size: 16
#   dropout_rate: 0.1
#   hidden_layer_sizes: (100,)
#   learning_rate_init: 0.001
#   max_iter: 30
#   solver: adam
#
#
# -- [pytorch_mlp_Comlex_protein_embeddings] best model parameters: {'activation': 'relu', 'batch_size': 16, 'dropout_rate': 0.1, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001, 'max_iter': 30, 'solver': 'adam'} --
# --------------------------------------------------------------------------------
# -- [pytorch_mlp_Comlex_protein_embeddings] predicting PYTORCH_MLP model on dataset 'Comlex_protein_embeddings' --
# --------------------------------------------------------------------------------
# -- Predictions made on test set --

# %%
mlp_classifiers[2].best_model
# Out:
# PyTorchMLP(batch_size=16, cache_dir='.cache/pytorch_mlp_plots/',
#            dropout_rate=0.1, hidden_layer_sizes=(100,), input_dim=200,
#            max_iter=30, name='Comlex_protein_embeddings_2.10_none',
#            random_state=2, solver='adamW')

# %%
classifiers=mlp_classifiers.copy()

# %% [markdown]
# ## evaluation

# %%
collector = ResultsCollector()
metrics_list = []
for i, ml_model in classifiers.items():
        print(f'-- Evaluating model{i}: {version} {norm} --')
        y_test, y_pred, y_proba = ml_model.y_test, ml_model.y_pred, ml_model.y_proba
        metrics = Evaluator(y_test, y_pred, y_proba).compute_metrics()
        metrics_list.append({
                        "model": ml_model.model_type,
                        "input": ml_model.dataset_name,
                        "normalization": norm,  
                        "version": version,
                        **metrics
                })

        collector.add(ml_model.model_type, ml_model.dataset_name, y_test, y_pred, y_proba)
results=pd.DataFrame(metrics_list)
# Out:
# -- Evaluating model0: 2.10 none --
# -- Evaluating model1: 2.10 none --
# -- Evaluating model2: 2.10 none --
# -- Evaluating model3: 2.10 none --
# -- Evaluating model4: 2.10 none --
# -- Evaluating model5: 2.10 none --
# -- Evaluating model6: 2.10 none --
# -- Evaluating model7: 2.10 none --
# -- Evaluating model8: 2.10 none --
# -- Evaluating model9: 2.10 none --

# %% [markdown]
# ## XGBOOST

# %%
results
# Out:
#      model                       input normalization version  \
# 0  xgboost  Complex_protein_embeddings          none    2.10
# 1  xgboost  Complex_protein_embeddings          none    2.10
# 2  xgboost  Complex_protein_embeddings          none    2.10
# 3  xgboost  Complex_protein_embeddings          none    2.10
# 4  xgboost  Complex_protein_embeddings          none    2.10
# 5  xgboost  Complex_protein_embeddings          none    2.10
# 6  xgboost  Complex_protein_embeddings          none    2.10
# 7  xgboost  Complex_protein_embeddings          none    2.10
# 8  xgboost  Complex_protein_embeddings          none    2.10
# 9  xgboost  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision  recall        f1       mcc     auroc  \
# 0           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 1           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 2           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 3           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 4           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 5           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 6           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 7           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 8           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
# 9           0.571429     0.8125     1.0  0.896552  0.340693  0.758242
#
#       auprc     brier
# 0  0.935417  0.179616
# 1  0.935417  0.179616
# 2  0.935417  0.179616
# 3  0.935417  0.179616
# 4  0.935417  0.179616
# 5  0.935417  0.179616
# 6  0.935417  0.179616
# 7  0.935417  0.179616
# 8  0.935417  0.179616
# 9  0.935417  0.179616

# %% [markdown]
# ### seed=1

# %%
results
# Out:
#      model                       input normalization version  \
# 0  xgboost  Complex_protein_embeddings          none    2.10
# 1  xgboost  Complex_protein_embeddings          none    2.10
# 2  xgboost  Complex_protein_embeddings          none    2.10
# 3  xgboost  Complex_protein_embeddings          none    2.10
# 4  xgboost  Complex_protein_embeddings          none    2.10
# 5  xgboost  Complex_protein_embeddings          none    2.10
# 6  xgboost  Complex_protein_embeddings          none    2.10
# 7  xgboost  Complex_protein_embeddings          none    2.10
# 8  xgboost  Complex_protein_embeddings          none    2.10
# 9  xgboost  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 0           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 1           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 2           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 3           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 4           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 5           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 6           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 7           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 8           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 9           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
#
#       auprc    brier
# 0  0.866611  0.17634
# 1  0.866611  0.17634
# 2  0.866611  0.17634
# 3  0.866611  0.17634
# 4  0.866611  0.17634
# 5  0.866611  0.17634
# 6  0.866611  0.17634
# 7  0.866611  0.17634
# 8  0.866611  0.17634
# 9  0.866611  0.17634

# %% [markdown]
# different seeds from 0 to 9

# %%
results
# Out:
#      model                       input normalization version  \
# 0  xgboost  Complex_protein_embeddings          none    2.10
# 1  xgboost  Complex_protein_embeddings          none    2.10
# 2  xgboost  Complex_protein_embeddings          none    2.10
# 3  xgboost  Complex_protein_embeddings          none    2.10
# 4  xgboost  Complex_protein_embeddings          none    2.10
# 5  xgboost  Complex_protein_embeddings          none    2.10
# 6  xgboost  Complex_protein_embeddings          none    2.10
# 7  xgboost  Complex_protein_embeddings          none    2.10
# 8  xgboost  Complex_protein_embeddings          none    2.10
# 9  xgboost  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 0           0.585165   0.821429  0.884615  0.851852  0.194206  0.796703
# 1           0.656593   0.851852  0.884615  0.867925  0.331957  0.653846
# 2           0.571429   0.812500  1.000000  0.896552  0.340693  0.912088
# 3           0.623626   0.833333  0.961538  0.892857  0.351605  0.890110
# 4           0.642857   0.838710  1.000000  0.912281  0.489522  0.862637
# 5           0.500000   0.787879  1.000000  0.881356  0.000000  0.670330
# 6           0.403846   0.750000  0.807692  0.777778 -0.219265  0.626374
# 7           0.513736   0.793103  0.884615  0.836364  0.034412  0.714286
# 8           0.618132   0.840000  0.807692  0.823529  0.225381  0.725275
# 9           0.695055   0.862069  0.961538  0.909091  0.488645  0.802198
#
#       auprc     brier
# 0  0.928977  0.138764
# 1  0.866611  0.176340
# 2  0.977070  0.172549
# 3  0.965485  0.104499
# 4  0.961242  0.165190
# 5  0.843229  0.182182
# 6  0.890819  0.198827
# 7  0.892860  0.165221
# 8  0.906419  0.174154
# 9  0.942572  0.149667

# %% [markdown]
# gene expression - different seeds from 0 to 9

# %%
results

# %% [markdown]
# ## SVM

# %%
results
# Out:
#   model                       input normalization version  balanced_accuracy  \
# 0   svm  Complex_protein_embeddings          none    2.10           0.766484
# 1   svm  Complex_protein_embeddings          none    2.10           0.766484
# 2   svm  Complex_protein_embeddings          none    2.10           0.766484
# 3   svm  Complex_protein_embeddings          none    2.10           0.766484
# 4   svm  Complex_protein_embeddings          none    2.10           0.766484
# 5   svm  Complex_protein_embeddings          none    2.10           0.766484
# 6   svm  Complex_protein_embeddings          none    2.10           0.766484
# 7   svm  Complex_protein_embeddings          none    2.10           0.766484
# 8   svm  Complex_protein_embeddings          none    2.10           0.766484
# 9   svm  Complex_protein_embeddings          none    2.10           0.766484
#
#    precision    recall        f1       mcc     auroc     auprc     brier
# 0   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 1   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 2   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 3   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 4   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 5   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 6   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 7   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 8   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555
# 9   0.892857  0.961538  0.925926  0.607676  0.873626  0.963271  0.106555

# %% [markdown]
# ## RANDOM FOREST

# %%
results
# Out:
#            model                       input normalization version  \
# 0  random_forest  Complex_protein_embeddings          none    2.10
# 1  random_forest  Complex_protein_embeddings          none    2.10
# 2  random_forest  Complex_protein_embeddings          none    2.10
# 3  random_forest  Complex_protein_embeddings          none    2.10
# 4  random_forest  Complex_protein_embeddings          none    2.10
# 5  random_forest  Complex_protein_embeddings          none    2.10
# 6  random_forest  Complex_protein_embeddings          none    2.10
# 7  random_forest  Complex_protein_embeddings          none    2.10
# 8  random_forest  Complex_protein_embeddings          none    2.10
# 9  random_forest  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision  recall        f1       mcc    auroc  \
# 0           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 1           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 2           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 3           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 4           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 5           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 6           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 7           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 8           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
# 9           0.714286   0.866667     1.0  0.928571  0.609449  0.82967
#
#       auprc     brier
# 0  0.940701  0.120954
# 1  0.940701  0.120954
# 2  0.940701  0.120954
# 3  0.940701  0.120954
# 4  0.940701  0.120954
# 5  0.940701  0.120954
# 6  0.940701  0.120954
# 7  0.940701  0.120954
# 8  0.940701  0.120954
# 9  0.940701  0.120954

# %% [markdown]
# ## SKLEARN MLP

# %%
MLModel.SKLEARN_MLP_HYPERPARAMS
# Out:
# {'hidden_layer_sizes': [(50,), (100,), (100, 50)],
#  'activation': ['relu'],
#  'solver': ['adam', 'sgd'],
#  'learning_rate_init': [0.001, 0.01, 0.1]}

# %% [markdown]
# ### with random seed and ES

# %%
results
# Out:
#          model                       input normalization version  \
# 0  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 1  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 2  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 3  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 4  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 5  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 6  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 7  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 8  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 9  sklearn_mlp  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision  recall        f1  mcc     auroc    auprc  \
# 0                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 1                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 2                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 3                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 4                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 5                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 6                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 7                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 8                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
# 9                0.5   0.787879     1.0  0.881356  0.0  0.587912  0.82071
#
#       brier
# 0  0.197344
# 1  0.197344
# 2  0.197344
# 3  0.197344
# 4  0.197344
# 5  0.197344
# 6  0.197344
# 7  0.197344
# 8  0.197344
# 9  0.197344

# %% [markdown]
# ### with seed without ES

# %%
results
# Out:
#          model                       input normalization version  \
# 0  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 1  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 2  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 3  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 4  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 5  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 6  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 7  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 8  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 9  sklearn_mlp  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision  recall        f1       mcc     auroc  \
# 0           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 1           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 2           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 3           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 4           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 5           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 6           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 7           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 8           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
# 9           0.714286   0.866667     1.0  0.928571  0.609449  0.912088
#
#       auprc     brier
# 0  0.976851  0.109176
# 1  0.976851  0.109176
# 2  0.976851  0.109176
# 3  0.976851  0.109176
# 4  0.976851  0.109176
# 5  0.976851  0.109176
# 6  0.976851  0.109176
# 7  0.976851  0.109176
# 8  0.976851  0.109176
# 9  0.976851  0.109176

# %% [markdown]
# #### gene expression

# %%
results
# Out:
#          model            input normalization version  balanced_accuracy  \
# 0  sklearn_mlp  gene_expression          none    2.10            0.89011
# 1  sklearn_mlp  gene_expression          none    2.10            0.89011
# 2  sklearn_mlp  gene_expression          none    2.10            0.89011
# 3  sklearn_mlp  gene_expression          none    2.10            0.89011
# 4  sklearn_mlp  gene_expression          none    2.10            0.89011
# 5  sklearn_mlp  gene_expression          none    2.10            0.89011
# 6  sklearn_mlp  gene_expression          none    2.10            0.89011
# 7  sklearn_mlp  gene_expression          none    2.10            0.89011
# 8  sklearn_mlp  gene_expression          none    2.10            0.89011
# 9  sklearn_mlp  gene_expression          none    2.10            0.89011
#
#    precision    recall        f1       mcc     auroc     auprc     brier
# 0       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 1       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 2       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 3       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 4       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 5       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 6       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 7       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 8       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761
# 9       0.96  0.923077  0.941176  0.744282  0.989011  0.997096  0.053761

# %% [markdown]
# ### without seed and earlystopping

# %%
results
# Out:
#          model                       input normalization version  \
# 0  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 1  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 2  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 3  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 4  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 5  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 6  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 7  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 8  sklearn_mlp  Complex_protein_embeddings          none    2.10
# 9  sklearn_mlp  Complex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 0           0.857143   0.928571  1.000000  0.962963  0.814411  0.928571
# 1           0.500000   0.787879  1.000000  0.881356  0.000000  0.673077
# 2           0.766484   0.892857  0.961538  0.925926  0.607676  0.763736
# 3           0.766484   0.892857  0.961538  0.925926  0.607676  0.785714
# 4           0.857143   0.928571  1.000000  0.962963  0.814411  0.835165
# 5           0.857143   0.928571  1.000000  0.962963  0.814411  0.851648
# 6           0.857143   0.928571  1.000000  0.962963  0.814411  0.807692
# 7           0.818681   0.923077  0.923077  0.923077  0.637363  0.747253
# 8           0.785714   0.896552  1.000000  0.945455  0.715762  0.714286
# 9           0.766484   0.892857  0.961538  0.925926  0.607676  0.758242
#
#       auprc     brier
# 0  0.979987  0.070701
# 1  0.861305  0.152247
# 2  0.887164  0.108444
# 3  0.918442  0.113651
# 4  0.940751  0.081638
# 5  0.950411  0.075100
# 6  0.922907  0.067840
# 7  0.902727  0.121159
# 8  0.865498  0.114461
# 9  0.872744  0.105568

# %%
results
# Out:
#          model                            input normalization version  \
# 0  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 1  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 2  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 3  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 4  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 5  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 6  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 7  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 8  sklearn_mlp  concatenated_protein_embeddings          none    2.10
# 9  sklearn_mlp  concatenated_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 0           0.500000   0.787879  1.000000  0.881356  0.000000  0.546703
# 1           0.428571   0.000000  0.000000  0.000000 -0.340693  0.428571
# 2           0.500000   0.787879  1.000000  0.881356  0.000000  0.500000
# 3           0.500000   0.787879  1.000000  0.881356  0.000000  0.500000
# 4           0.747253   0.888889  0.923077  0.905660  0.524142  0.747253
# 5           0.500000   0.787879  1.000000  0.881356  0.000000  0.434066
# 6           0.500000   0.787879  1.000000  0.881356  0.000000  0.453297
# 7           0.500000   0.787879  1.000000  0.881356  0.000000  0.500000
# 8           0.500000   0.000000  0.000000  0.000000  0.000000  0.500000
# 9           0.428571   0.000000  0.000000  0.000000 -0.340693  0.428571
#
#       auprc     brier
# 0  0.803882  0.202548
# 1  0.787879  0.799673
# 2  0.787879  0.211097
# 3  0.787879  0.173484
# 4  0.881119  0.151515
# 5  0.769231  0.186358
# 6  0.773726  0.208511
# 7  0.787879  0.167237
# 8  0.787879  0.251281
# 9  0.787879  0.285042

# %%
results
# Out:
#          model            input normalization version  balanced_accuracy  \
# 0  sklearn_mlp  gene_expression          none    2.10           0.928571
# 1  sklearn_mlp  gene_expression          none    2.10           1.000000
# 2  sklearn_mlp  gene_expression          none    2.10           0.785714
# 3  sklearn_mlp  gene_expression          none    2.10           0.837912
# 4  sklearn_mlp  gene_expression          none    2.10           0.980769
# 5  sklearn_mlp  gene_expression          none    2.10           0.961538
# 6  sklearn_mlp  gene_expression          none    2.10           0.980769
# 7  sklearn_mlp  gene_expression          none    2.10           0.818681
# 8  sklearn_mlp  gene_expression          none    2.10           0.909341
# 9  sklearn_mlp  gene_expression          none    2.10           0.890110
#
#    precision    recall        f1       mcc     auroc     auprc     brier
# 0   0.962963  1.000000  0.981132  0.908514  1.000000  1.000000  0.020148
# 1   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  0.014521
# 2   0.896552  1.000000  0.945455  0.715762  0.901099  0.954977  0.090989
# 3   0.925926  0.961538  0.943396  0.716328  0.906593  0.966990  0.087382
# 4   1.000000  0.961538  0.980392  0.917249  1.000000  1.000000  0.030303
# 5   1.000000  0.923077  0.960000  0.847319  0.989011  0.997096  0.059941
# 6   1.000000  0.961538  0.980392  0.917249  1.000000  1.000000  0.030303
# 7   0.923077  0.923077  0.923077  0.637363  0.967033  0.991445  0.084155
# 8   0.961538  0.961538  0.961538  0.818681  0.994505  0.998575  0.047230
# 9   0.960000  0.923077  0.941176  0.744282  0.923077  0.960173  0.090909

# %% [markdown]
# ## PYTORCH MLP

# %%
MLModel.PYTORCH_MLP_HYPERPARAMS
# Out:
# {'hidden_layer_sizes': [(50,), (100,)],
#  'max_iter': [30],
#  'activation': ['relu'],
#  'solver': ['adam', 'adamW'],
#  'learning_rate_init': [0.001, 0.0001],
#  'batch_size': [16],
#  'dropout_rate': [0.0, 0.1]}

# %%
results
# Out:
#          model                      input normalization version  \
# 0  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 1  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 2  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 3  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 4  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 5  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 6  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 7  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 8  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 9  pytorch_mlp  Comlex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 0           0.780220   0.916667  0.846154  0.880000  0.514443  0.846154
# 1           0.695055   0.862069  0.961538  0.909091  0.488645  0.752747
# 2           0.500000   0.787879  1.000000  0.881356  0.000000  0.923077
# 3           0.695055   0.862069  0.961538  0.909091  0.488645  0.857143
# 4           0.708791   0.880000  0.846154  0.862745  0.398348  0.879121
# 5           0.728022   0.884615  0.884615  0.884615  0.456044  0.873626
# 6           0.552198   0.806452  0.961538  0.877193  0.178864  0.571429
# 7           0.571429   0.812500  1.000000  0.896552  0.340693  0.692308
# 8           0.780220   0.916667  0.846154  0.880000  0.514443  0.725275
# 9           0.623626   0.833333  0.961538  0.892857  0.351605  0.785714
#
#       auprc     brier
# 0  0.948349  0.133256
# 1  0.916476  0.129246
# 2  0.982263  0.141148
# 3  0.949759  0.117453
# 4  0.968441  0.126289
# 5  0.969512  0.143174
# 6  0.829773  0.175431
# 7  0.897578  0.150943
# 8  0.878999  0.165041
# 9  0.906006  0.129698

# %% [markdown]
# 20 epochs 10 different seeds from 0 to 9, dropout rate as hyperparam (0 and 0.1) (adamw and adam, 0.001 0.0001)

# %%
MLModel.PYTORCH_MLP_HYPERPARAMS
# Out:
# {'hidden_layer_sizes': [(50,), (100,)],
#  'max_iter': [20],
#  'activation': ['relu'],
#  'solver': ['adam', 'adamW'],
#  'learning_rate_init': [0.001, 0.0001],
#  'batch_size': [16],
#  'dropout_rate': [0.0, 0.1]}

# %%
results
# Out:
#          model                      input normalization version  \
# 0  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 1  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 2  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 3  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 4  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 5  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 6  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 7  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 8  pytorch_mlp  Comlex_protein_embeddings          none    2.10
# 9  pytorch_mlp  Comlex_protein_embeddings          none    2.10
#
#    balanced_accuracy  precision    recall        f1       mcc     auroc  \
# 0           0.818681   0.923077  0.923077  0.923077  0.637363  0.851648
# 1           0.642857   0.838710  1.000000  0.912281  0.489522  0.631868
# 2           0.500000   0.787879  1.000000  0.881356  0.000000  0.774725
# 3           0.623626   0.833333  0.961538  0.892857  0.351605  0.840659
# 4           0.708791   0.880000  0.846154  0.862745  0.398348  0.846154
# 5           0.552198   0.806452  0.961538  0.877193  0.178864  0.626374
# 6           0.500000   0.787879  1.000000  0.881356  0.000000  0.368132
# 7           0.489011   0.782609  0.692308  0.734694 -0.019551  0.489011
# 8           0.500000   0.787879  1.000000  0.881356  0.000000  0.576923
# 9           0.571429   0.812500  1.000000  0.896552  0.340693  0.807692
#
#       auprc     brier
# 0  0.936591  0.104532
# 1  0.822137  0.135552
# 2  0.945973  0.150741
# 3  0.939258  0.133625
# 4  0.955569  0.142327
# 5  0.892344  0.174286
# 6  0.740299  0.195708
# 7  0.817266  0.283978
# 8  0.789776  0.171680
# 9  0.910470  0.115856
