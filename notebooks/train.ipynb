# %% [markdown]
# This notebook aim to train all models on all datasets

# %%
import os,sys
from joblib import Parallel, delayed,dump,load

sys.path.append(os.path.abspath('../src/ml'))
from load_matrix import load_df
from model_trainer import MLModel
from utils import load_models

# %% [markdown]
# Experimenting with different constants and parameters for the models

# %%
# set_num_threads(4)
train_all(model_types=['pytorch_mlp'],version='v2.10',datasets=['RGCN_sample_embeddings'])
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [PID 186241] Training model: pytorch_mlp  on dataset: RGCN_sample_embeddings
# -- [pytorch_mlp_RGCN_sample_embeddings] Initialized MLModel with model_type='PYTORCH_MLP', dataset_name='RGCN_SAMPLE_EMBEDDINGS' --
# -- [pytorch_mlp_RGCN_sample_embeddings] split ratio: 0.2
# -- [pytorch_mlp_RGCN_sample_embeddings] random state: 42
# -- [pytorch_mlp_RGCN_sample_embeddings] trained model will be saved to: /mnt/c/Users/rayan/Documents/saclay/courses/deep-learning-and-artifical-intelligence/project/dump/v2.10 --
# -- [pytorch_mlp_RGCN_sample_embeddings] logging in f../../dump/logs --
# --------------------------------------------------------------------------------
# -- [pytorch_mlp_RGCN_sample_embeddings] Training PYTORCH_MLP model on dataset 'RGCN_sample_embeddings' --
# --------------------------------------------------------------------------------
#
# -- MLP Hyperparameters --
# {   'activation': ['relu', 'tanh'],
#     'batch_size': [16, 32, 64],
#     'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)],
#     'learning_rate_init': [0.001, 0.01, 0.1],
#     'solver': ['adam', 'sgd']}
